# %% [markdown]
# # Environment Initialization and Dataset Verification
# <p style="font-size:18px; font-weight:normal;">
#  This cell imports essential libraries (NumPy, Pandas, os) and verifies that the dataset is correctly mounted in the Kaggle environment.
#  It lists all files under /kaggle/input to ensure that video data is accessible before model training.
#  </p>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/479_706.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/481_469.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/184_205.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/315_322.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/645_688.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/700_813.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/313_283.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/336_338.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/746_571.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/917_924.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/207_908.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/297_270.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/692_610.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/179_212.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/936_931.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/562_626.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/074_825.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/392_339.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/673_728.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/914_899.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/415_484.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/601_653.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/261_254.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/213_083.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/478_506.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/208_215.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/651_835.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/370_483.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/855_801.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/351_346.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/992_980.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/588_556.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/724_725.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/793_768.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/003_000.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/982_004.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/105_180.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/579_701.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/784_769.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/236_237.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/345_259.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/262_301.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/275_887.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/902_901.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/835_651.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/894_848.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/575_603.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/026_012.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/789_753.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/417_496.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/540_536.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/241_210.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/039_058.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/406_391.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/553_545.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/552_851.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/560_557.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/171_173.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/030_193.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/795_907.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/366_473.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/237_236.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/904_046.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/089_065.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/270_297.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/822_244.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/925_933.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/879_963.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/100_077.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/598_178.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/948_965.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/747_854.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/964_174.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/654_648.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/949_868.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/665_679.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/727_729.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/652_773.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/435_456.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/234_187.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/969_897.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/072_037.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/343_363.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/495_512.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/472_511.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/763_930.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/735_774.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/807_273.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/284_263.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/853_863.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/358_380.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/957_959.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/066_062.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/908_207.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/009_027.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/256_146.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/038_125.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/756_503.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/882_952.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/489_022.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/691_732.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/225_151.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/014_790.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/300_304.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/407_374.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/251_375.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/071_054.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/755_759.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/637_427.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/375_251.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/154_386.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/681_711.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/587_535.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/523_541.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/378_368.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/145_299.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/538_493.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/440_364.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/490_534.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/694_767.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/983_113.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/635_642.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/865_739.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/823_584.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/328_320.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/706_479.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/961_069.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/672_720.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/013_883.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/226_491.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/611_760.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/405_393.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/468_470.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/365_307.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/840_800.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/362_354.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/469_481.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/122_144.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/786_819.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/537_563.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/316_369.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/120_118.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/190_176.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/976_954.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/839_864.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/841_639.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/044_945.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/390_709.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/966_988.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/633_529.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/456_435.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/452_550.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/715_721.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/436_526.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/247_229.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/730_815.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/749_659.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/827_817.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/734_699.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/647_622.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/094_111.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/623_630.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/132_007.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/235_194.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/104_126.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/728_673.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/248_232.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/474_281.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/295_099.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/549_531.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/465_482.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/055_147.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/669_682.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/281_474.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/630_623.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/401_395.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/927_912.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/800_840.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/674_744.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/583_558.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/564_971.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/083_213.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/603_575.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/850_764.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/462_467.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/314_347.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/521_517.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/033_097.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/794_779.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/788_710.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/288_321.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/720_672.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/330_162.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/034_590.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/688_645.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/501_326.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/254_261.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/545_553.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/402_453.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/576_155.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/112_892.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/656_666.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/050_059.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/667_446.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/731_741.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/754_758.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/455_471.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/411_410.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/389_480.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/987_938.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/416_342.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/614_616.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/764_850.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/719_737.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/193_030.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/113_983.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/428_466.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/857_909.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/620_619.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/364_440.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/144_122.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/996_056.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/542_520.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/165_137.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/534_490.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/679_665.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/874_291.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/526_436.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/847_906.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/998_561.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/639_841.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/245_157.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/233_995.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/492_325.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/825_074.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/770_791.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/814_871.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/870_001.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/616_614.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/684_717.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/609_596.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/871_814.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/221_206.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/714_842.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/878_866.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/937_888.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/989_993.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/898_922.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/796_740.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/893_913.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/331_260.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/467_462.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/573_757.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/228_289.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/170_186.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/524_580.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/624_570.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/568_628.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/498_433.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/952_882.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/875_979.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/224_197.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/022_489.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/181_199.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/141_161.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/977_075.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/687_615.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/093_121.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/325_492.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/762_832.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/555_516.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/926_900.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/376_381.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/045_889.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/398_457.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/493_538.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/979_875.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/460_678.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/293_296.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/584_823.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/711_681.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/968_884.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/125_038.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/446_667.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/888_937.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/200_189.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/689_690.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/292_294.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/648_654.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/040_997.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/995_233.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/451_449.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/205_184.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/805_011.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/717_684.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/475_265.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/084_042.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/214_255.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/289_228.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/596_609.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/512_495.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/660_634.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/935_733.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/903_792.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/471_455.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/438_434.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/950_836.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/707_705.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/142_138.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/748_355.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/422_695.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/861_858.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/954_976.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/049_946.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/317_359.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/178_598.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/349_350.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/000_003.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/890_837.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/758_754.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/168_222.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/828_830.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/815_730.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/565_589.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/972_718.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/548_632.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/508_831.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/702_612.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/374_407.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/363_343.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/819_786.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/643_646.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/450_533.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/934_918.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/384_932.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/586_223.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/943_942.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/432_357.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/486_680.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/087_081.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/607_683.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/939_115.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/344_020.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/174_964.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/741_731.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/539_499.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/413_372.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/021_312.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/953_974.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/338_336.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/722_458.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/696_686.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/148_133.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/500_592.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/543_559.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/219_220.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/239_218.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/670_661.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/781_806.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/371_367.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/900_926.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/602_397.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/597_595.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/813_700.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/868_949.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/530_594.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/273_807.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/622_647.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/956_958.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/811_920.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/528_510.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/504_502.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/592_500.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/750_743.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/176_190.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/252_266.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/872_873.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/940_941.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/149_152.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/290_240.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/891_876.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/098_092.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/744_674.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/941_940.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/059_050.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/086_090.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/037_072.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/322_315.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/302_323.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/396_272.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/682_669.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/128_896.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/974_953.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/701_579.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/457_398.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/191_188.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/867_765.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/676_776.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/454_527.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/326_501.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/152_149.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/824_419.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/556_588.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/320_328.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/973_970.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/028_068.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/211_177.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/166_167.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/032_944.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/210_241.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/442_195.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/306_278.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/808_829.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/399_488.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/653_601.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/988_966.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/453_402.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/733_935.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/842_714.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/944_032.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/566_617.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/664_668.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/686_696.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/561_998.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/834_852.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/260_331.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/035_036.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/304_300.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/551_631.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/675_608.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/685_613.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/799_809.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/118_120.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/073_024.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/529_633.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/332_051.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/346_351.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/783_916.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/182_242.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/659_749.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/488_399.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/119_123.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/608_675.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/930_763.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/268_269.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/921_569.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/140_143.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/437_360.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/312_021.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/311_387.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/876_891.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/427_637.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/339_392.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/321_288.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/081_087.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/350_349.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/090_086.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/849_771.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/352_319.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/574_547.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/932_384.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/519_515.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/271_264.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/294_292.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/668_664.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/738_804.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/975_978.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/110_043.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/197_224.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/473_366.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/250_461.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/531_549.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/463_464.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/319_352.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/373_394.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/186_170.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/101_096.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/559_543.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/048_029.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/133_148.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/274_412.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/933_925.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/058_039.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/445_494.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/869_780.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/443_514.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/006_002.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/831_508.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/577_593.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/075_977.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/491_226.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/634_660.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/278_306.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/419_824.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/683_607.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/391_406.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/703_604.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/820_818.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/157_245.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/723_704.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/116_091.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/631_551.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/136_285.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/082_103.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/047_862.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/175_159.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/485_425.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/158_379.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/563_537.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/899_914.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/775_742.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/779_794.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/015_919.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/766_761.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/680_486.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/377_333.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/801_855.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/280_249.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/757_573.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/958_956.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/513_305.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/369_316.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/984_967.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/307_365.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/203_201.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/359_317.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/444_655.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/852_834.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/671_677.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/425_485.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/725_724.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/970_973.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_fake/243_156.mp4
# ...
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/550.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/785.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/887.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/700.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/609.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/526.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/183.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/124.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/156.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/342.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/445.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/549.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/337.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/838.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/118.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/707.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/418.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/110.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/477.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/300.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/006.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/230.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/108.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/943.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/451.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/306.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/155.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/202.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/179.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/454.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/104.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/763.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/938.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/756.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/007.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/143.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/575.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/955.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/882.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/804.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/281.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/257.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/150.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/407.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/966.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/023.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/916.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/915.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/578.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/243.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/137.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/903.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/378.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/393.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/963.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/911.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/599.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/358.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/486.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/721.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/275.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/950.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/041.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/945.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/404.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/644.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/287.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/910.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/727.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/439.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/492.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/073.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/687.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/271.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/076.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/962.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/710.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/140.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/730.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/225.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/948.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/761.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/863.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/157.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/339.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/443.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/936.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/380.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/368.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/624.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/794.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/434.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/282.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/385.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/517.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/867.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/939.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/064.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/349.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/788.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/169.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/688.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/664.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/655.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/188.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/829.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/133.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/036.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/475.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/970.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/620.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/988.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/056.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/458.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/471.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/545.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/293.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/206.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/717.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/267.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/808.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/505.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/627.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/024.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/856.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/637.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/612.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/720.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/852.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/739.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/619.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/821.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/682.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/192.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/653.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/269.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/005.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/512.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/063.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/523.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/315.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/218.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/557.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/983.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/255.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/398.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/450.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/986.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/084.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/094.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/814.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/781.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/119.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/432.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/495.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/379.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/396.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/909.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/175.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/097.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/210.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/977.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/240.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/616.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/440.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/651.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/467.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/200.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/261.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/373.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/198.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/325.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/666.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/605.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/103.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/412.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/217.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/151.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/597.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/723.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/135.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/497.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/764.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/669.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/361.mp4
# /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/789.mp4

# %%
import torch
import torchvision
import timm
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# Install dependencies

# !pip -q install timm decord grad-cam --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 70.9 MB/s eta 0:00:00:00:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 86.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 94.9 MB/s eta 0:00:00:00:010:01
#   Building wheel for grad-cam (pyproject.toml) ... done

# %% [markdown]
# # Imports & Reproducibility Setup
#
# <p style="font-size:18px; font-weight:normal;">
# This cell imports all required libraries for deep learning, video and audio processing, and model evaluation.
# It also sets a fixed random seed to ensure reproducibility and defines the computation device (CPU/GPU) for training.
# </p>

# %%
#  Imports & Seed

import os, glob, re, random, math, time, hashlib, subprocess
import numpy as np
import pandas as pd
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler

from decord import VideoReader, cpu
import timm
import torchaudio

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

import matplotlib.pyplot as plt

SEED = 42
def seed_everything(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

seed_everything()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # Configuration Settings
#
# <p style="font-size:18px; font-weight:normal;">
# This section defines all global hyperparameters and training settings used throughout the project, including image size, number of frames, learning rates, batch size, and audio parameters.
# It centralizes configuration values to ensure consistency, reproducibility, and easy experimentation.
# </p>

# %%
@dataclass
class CFG:
    img_size: int = 224
    k_frames: int = 16
    batch_size: int = 4
    num_workers: int = 2
    epochs_baseline: int = 4
    epochs_av: int = 6
    lr_baseline: float = 3e-4
    lr_av: float = 2e-4
    weight_decay: float = 1e-4
    patience: int = 2
    sample_rate: int = 16000
    audio_seconds: int = 4
    n_mfcc: int = 40
    audio_cache_dir: str = "/kaggle/working/audio_cache"
    work_dir: str = "/kaggle/working"

cfg = CFG()
os.makedirs(cfg.audio_cache_dir, exist_ok=True)

MEAN = (0.485, 0.456, 0.406)
STD  = (0.229, 0.224, 0.225)

# %% [markdown]
# # Video Sampling and Preprocessing
#
# <p style="font-size:18px; font-weight:normal;">
# This section defines helper functions for extracting and preprocessing video frames.
# It samples a fixed number of frames per video, applies optional data augmentation, and performs center-crop resizing to ensure consistent input dimensions for the model.
# </p>

# %%
def sample_frame_indices(num_frames_total, k=16, strategy="uniform"):
    if num_frames_total <= 0:
        return np.zeros((k,), dtype=np.int64)
    if strategy == "uniform":
        idx = np.linspace(0, num_frames_total - 1, k).round().astype(np.int64)
        return idx
    if strategy == "random":
        if num_frames_total >= k:
            start = random.randint(0, num_frames_total - k)
            return np.arange(start, start + k, dtype=np.int64)
        else:
            idx = np.arange(num_frames_total, dtype=np.int64)
            pad = np.full((k - num_frames_total,), num_frames_total - 1, dtype=np.int64)
            return np.concatenate([idx, pad])
    raise ValueError("Unknown strategy")

def random_horizontal_flip(frames, p=0.5):
    if random.random() < p:
        return frames[:, :, ::-1, :]
    return frames

def center_crop_resize(frames, out_size=224):
    # frames: (T,H,W,3) uint8
    import cv2
    out = []
    for fr in frames:
        h, w, _ = fr.shape
        scale = out_size / min(h, w)
        nh, nw = int(h * scale), int(w * scale)
        fr = cv2.resize(fr, (nw, nh), interpolation=cv2.INTER_AREA)
        h, w, _ = fr.shape
        y0 = (h - out_size) // 2
        x0 = (w - out_size) // 2
        fr = fr[y0:y0 + out_size, x0:x0 + out_size]
        out.append(fr)
    return np.stack(out, axis=0)

# %% [markdown]
# # Audio Feature Extraction (MFCC)
#
# <p style="font-size:18px; font-weight:normal;">
# This section extracts audio features from each video using MFCC representations.
# Audio is converted to mono 16kHz format, standardized in length, and transformed into MFCC coefficients. If no audio is available, a zero tensor is returned to maintain consistent input dimensions.
# </p>

# %%
SAMPLE_RATE = cfg.sample_rate
N_MFCC = cfg.n_mfcc

mfcc_tf = torchaudio.transforms.MFCC(
    sample_rate=SAMPLE_RATE,
    n_mfcc=N_MFCC,
    melkwargs={"n_fft": 400, "hop_length": 160, "n_mels": 64, "center": True},
)

def audio_path_for_video(video_path: str):
    h = hashlib.md5(video_path.encode("utf-8")).hexdigest()
    return os.path.join(cfg.audio_cache_dir, f"{h}.wav")

def ensure_audio(video_path: str):
    out = audio_path_for_video(video_path)
    if os.path.exists(out) and os.path.getsize(out) > 1000:
        return out
    # extract audio from mp4 -> wav mono 16k
    cmd = [
    "ffmpeg",
    "-y",
    "-loglevel", "quiet",
    "-i", video_path,
    "-vn",
    "-ac", "1",
    "-ar", str(SAMPLE_RATE),
    out
]

    try:
        subprocess.run(cmd, check=False, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        if os.path.exists(out) and os.path.getsize(out) > 1000:
            return out
    except Exception:
        pass
    return None  # if no audio or ffmpeg failed

def load_mfcc_or_zeros(video_path: str):
    apath = ensure_audio(video_path)
    if apath is None:
        # Return consistent shape zeros (n_mfcc, time)
        return torch.zeros((N_MFCC, 401), dtype=torch.float32)

    wav, sr = torchaudio.load(apath)
    wav = wav.mean(dim=0, keepdim=True)  # mono
    if sr != SAMPLE_RATE:
        wav = torchaudio.functional.resample(wav, sr, SAMPLE_RATE)

    target_len = SAMPLE_RATE * cfg.audio_seconds
    if wav.shape[1] >= target_len:
        wav = wav[:, :target_len]
    else:
        wav = F.pad(wav, (0, target_len - wav.shape[1]))

    mfcc = mfcc_tf(wav)          # (1, n_mfcc, time)
    mfcc = torch.log1p(mfcc)
    return mfcc.squeeze(0)       # (n_mfcc, time)

# %% [markdown]
# # Dataset Discovery and Automatic Label Inference
#
# <p style="font-size:18px; font-weight:normal;">
# This section scans the FaceForensics++ dataset to locate all video files and automatically assign binary labels based on directory naming conventions.
# Videos labeled as "original/pristine" are assigned class 0 (real), while manipulated methods (e.g., DeepFakes, FaceSwap) are assigned class 1 (fake).
# </p>

# %%
def find_all_mp4(base="/kaggle/input"):
    mp4s = glob.glob(base + "/**/*.mp4", recursive=True)
    print("Found mp4:", len(mp4s))
    return mp4s

mp4s = find_all_mp4()

# Label inference: FaceForensics++ usually has "original" vs manipulated methods
# We'll treat:
#  - Original / pristine / real => label 0
#  - Anything under manipulated methods (deepfakes, face2face, faceswap, neuraltextures, etc) => label 1
FAKE_KEYS = [
    "deepfakes", "face2face", "faceswap", "neuraltextures", "manipulated",
    "fake", "df", "f2f", "fs", "nt"
]
REAL_KEYS = ["original", "pristine", "real"]

def infer_label_ffpp(path: str):
    s = path.lower()
    if any(k in s for k in REAL_KEYS) and not any(k in s for k in FAKE_KEYS):
        return 0
    if any(k in s for k in FAKE_KEYS) and not any(k in s for k in REAL_KEYS):
        return 1
    # If ambiguous, we try a stronger rule:
    # if contains "original" anywhere -> real
    if "original" in s or "pristine" in s:
        return 0
    # otherwise if contains known manip methods -> fake
    if any(k in s for k in ["deepfakes", "face2face", "faceswap", "neuraltextures"]):
        return 1
    return None

rows = []
for p in mp4s:
    y = infer_label_ffpp(p)
    if y is not None:
        rows.append({"video_path": p, "label": y})

df = pd.DataFrame(rows)
print("Labeled videos:", len(df), "out of", len(mp4s))
if len(df) == 0:
    raise RuntimeError("Could not infer labels. Print mp4 paths and adjust infer_label_ffpp().")

print("Label distribution:", df["label"].value_counts().to_dict())
print(df.sample(5, random_state=SEED))
# Out:
# Found mp4: 2000
# Labeled videos: 2000 out of 2000
# Label distribution: {1: 1000, 0: 1000}
#                                              video_path  label
# 1860  /kaggle/input/datasets/rohingarg12/faceforensi...      0
# 353   /kaggle/input/datasets/rohingarg12/faceforensi...      1
# 1333  /kaggle/input/datasets/rohingarg12/faceforensi...      0
# 905   /kaggle/input/datasets/rohingarg12/faceforensi...      1
# 1289  /kaggle/input/datasets/rohingarg12/faceforensi...      0

# %% [markdown]
# # Train, Validation, and Test Split
#
# <p style="font-size:18px; font-weight:normal;">
# This section removes duplicate entries and performs a stratified split of the dataset into training (70%), validation (15%), and test (15%) sets.
# Stratification ensures balanced class distribution across all subsets, and the splits are saved as CSV files for reproducibility.
# </p>

# %%
df = df.drop_duplicates(subset=["video_path"]).reset_index(drop=True)

# Stratified split
train_df, tmp_df = train_test_split(df, test_size=0.30, random_state=SEED, stratify=df["label"])
val_df, test_df  = train_test_split(tmp_df, test_size=0.50, random_state=SEED, stratify=tmp_df["label"])

train_csv = os.path.join(cfg.work_dir, "train.csv")
val_csv   = os.path.join(cfg.work_dir, "val.csv")
test_csv  = os.path.join(cfg.work_dir, "test.csv")

train_df.to_csv(train_csv, index=False)
val_df.to_csv(val_csv, index=False)
test_df.to_csv(test_csv, index=False)

print("Saved:", train_csv, val_csv, test_csv)
print("Train:", train_df["label"].value_counts().to_dict())
print("Val  :", val_df["label"].value_counts().to_dict())
print("Test :", test_df["label"].value_counts().to_dict())
# Out:
# Saved: /kaggle/working/train.csv /kaggle/working/val.csv /kaggle/working/test.csv
# Train: {0: 700, 1: 700}
# Val  : {1: 150, 0: 150}
# Test : {1: 150, 0: 150}

# %% [markdown]
# # Custom Dataset and DataLoaders
#
# <p style="font-size:18px; font-weight:normal;">
# This section defines a custom PyTorch Dataset that loads video frames and corresponding audio features for each sample.
# Video frames are sampled, augmented (during training), normalized, and converted to tensors, while MFCC audio features are extracted and aligned. DataLoaders are then created for efficient batch processing.
# </p>

# %%
class RealVisionDataset(Dataset):
    def __init__(self, csv_path, k_frames=16, train=True):
        self.df = pd.read_csv(csv_path)
        self.k_frames = k_frames
        self.train = train
        assert set(self.df["label"].unique()).issubset({0,1})

    def _load_video_frames(self, video_path):
        vr = VideoReader(video_path, ctx=cpu(0))
        n = len(vr)
        idx = sample_frame_indices(n, k=self.k_frames, strategy="uniform")
        frames = vr.get_batch(idx).asnumpy()  # (T,H,W,3)

        if self.train:
            frames = random_horizontal_flip(frames, p=0.5)

        frames = center_crop_resize(frames, out_size=cfg.img_size)
        x = torch.from_numpy(frames).float() / 255.0
        x = x.permute(0,3,1,2)  # (T,3,H,W)
        # --- ImageNet normalization ---
        mean = torch.tensor(MEAN).view(1,3,1,1)
        std  = torch.tensor(STD).view(1,3,1,1)
        x = (x - mean) / std
        return x

    def __len__(self):
        return len(self.df)

    def __getitem__(self, i):
        row = self.df.iloc[i]
        vpath = row["video_path"]
        y = int(row["label"])

        v = self._load_video_frames(vpath)
        a = load_mfcc_or_zeros(vpath)  # (n_mfcc, time)
        return v, a, torch.tensor(y, dtype=torch.long)

train_ds = RealVisionDataset(train_csv, k_frames=cfg.k_frames, train=True)
val_ds   = RealVisionDataset(val_csv,   k_frames=cfg.k_frames, train=False)
test_ds  = RealVisionDataset(test_csv,  k_frames=cfg.k_frames, train=False)

train_loader = DataLoader(train_ds, batch_size=cfg.batch_size, shuffle=True,
                          num_workers=cfg.num_workers, pin_memory=True, drop_last=True)
val_loader   = DataLoader(val_ds, batch_size=cfg.batch_size, shuffle=False,
                          num_workers=cfg.num_workers, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=cfg.batch_size, shuffle=False,
                          num_workers=cfg.num_workers, pin_memory=True)

# %% [markdown]
# # Data Sanity Checks
#
# <p style="font-size:18px; font-weight:normal;">
# This section performs basic sanity checks to verify correct data loading before training.
# It confirms balanced class distribution, validates input tensor shapes (video and audio), and prints a sample video path to ensure dataset integrity.
# </p>

# %%
from collections import Counter
print("Train label counts:", Counter(train_ds.df["label"].tolist()))

v, a, y = train_ds[0]
print("Sample shapes:", v.shape, a.shape, y.item())
print("First video path:", train_ds.df.iloc[0]["video_path"])
# Out:
# Train label counts: Counter({0: 700, 1: 700})
# Sample shapes: torch.Size([16, 3, 224, 224]) torch.Size([40, 401]) 0
# First video path: /kaggle/input/datasets/rohingarg12/faceforensics-1000/face++dataset/ffpp_real/673.mp4

# %% [markdown]
# # Model Architectures
#
# <p style="font-size:18px; font-weight:normal;">
# This section defines the model architectures used in the project.
# A video-only baseline model is implemented using a pre-trained EfficientNet backbone, while the main multi-modal model integrates spatial video features, temporal modeling via a Transformer encoder, and audio embeddings through MFCC-based convolutional layers.
# </p>

# %%
class VideoOnlyBaseline(nn.Module):
    def __init__(self, backbone="tf_efficientnet_b0", emb_dim=256):
        super().__init__()
        self.cnn = timm.create_model(backbone, pretrained=True, num_classes=0, global_pool="")
        ch = self.cnn.num_features
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.proj = nn.Linear(ch, emb_dim)
        self.classifier = nn.Linear(emb_dim, 2)

    def forward(self, v):  # (B,T,3,H,W)
        B,T,C,H,W = v.shape
        x = v.view(B*T, C, H, W)
        feat = self.cnn(x)
        if feat.dim() == 4:
            feat = self.pool(feat).flatten(1)
        feat = feat.view(B, T, -1).mean(dim=1)
        feat = self.proj(feat)
        return self.classifier(feat)

class AudioEncoder(nn.Module):
    def __init__(self, n_mfcc=40, emb_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(n_mfcc, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, 256, kernel_size=5, padding=2),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1),
        )
        self.proj = nn.Linear(256, emb_dim)

    def forward(self, a):  # (B, n_mfcc, time)
        x = self.net(a).squeeze(-1)      # (B,256)
        return self.proj(x)

class RealVisionAV(nn.Module):
    def __init__(self, backbone="tf_efficientnet_b0", v_emb=256, a_emb=256, nheads=4, nlayers=2):
        super().__init__()
        self.cnn = timm.create_model(backbone, pretrained=True, num_classes=0, global_pool="")
        ch = self.cnn.num_features
        self.v_pool = nn.AdaptiveAvgPool2d(1)
        self.v_proj = nn.Linear(ch, v_emb)

        enc_layer = nn.TransformerEncoderLayer(d_model=v_emb, nhead=nheads, batch_first=True)
        self.temporal = nn.TransformerEncoder(enc_layer, num_layers=nlayers)

        self.audio = AudioEncoder(n_mfcc=N_MFCC, emb_dim=a_emb)

        self.fusion = nn.Sequential(
            nn.Linear(v_emb + a_emb, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 2)
        )

    def forward(self, v, a):
        # v: (B,T,3,H,W), a: (B,n_mfcc,time)
        B,T,C,H,W = v.shape
        x = v.view(B*T, C, H, W)
        feat = self.cnn(x)
        if feat.dim() == 4:
            feat = self.v_pool(feat).flatten(1)
        feat = feat.view(B, T, -1)
        feat = self.v_proj(feat)          # (B,T,v_emb)

        feat = self.temporal(feat)        # (B,T,v_emb)
        v_emb = feat.mean(dim=1)          # (B,v_emb)
        a_emb = self.audio(a)             # (B,a_emb)

        alpha = 0.3
        fused = torch.cat([v_emb, a_emb], dim=1)
        return self.fusion(fused)

# %% [markdown]
# # Training Strategy and Evaluation Metrics
#
# <p style="font-size:18px; font-weight:normal;">
# This section defines the training loop, evaluation metrics (Accuracy, F1-score, AUC), and optimization strategy.
# The model is trained using weighted cross-entropy to address potential class imbalance, AdamW optimization, cosine learning rate scheduling, and early stopping based on validation F1-score.
# </p>

# %%
def compute_metrics(y_true, y_prob):
    y_pred = (y_prob[:,1] >= 0.5).astype(int)
    acc = accuracy_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred)
    try:
        auc = roc_auc_score(y_true, y_prob[:,1])
    except:
        auc = float("nan")
    return acc, f1, auc

def get_class_weights_from_train(train_df):
    counts = train_df["label"].value_counts().to_dict()
    w0 = 1.0 / max(counts.get(0,1), 1)
    w1 = 1.0 / max(counts.get(1,1), 1)
    w = torch.tensor([w0, w1], dtype=torch.float32, device=device)
    return w

def train_one_epoch(model, loader, optimizer, scaler, criterion, is_av: bool):
    model.train()
    losses, all_y, all_p = [], [], []
    for v,a,y in loader:
        v = v.to(device, non_blocking=True)
        a = a.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        with autocast():
            logits = model(v,a) if is_av else model(v)
            loss = criterion(logits, y)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        losses.append(loss.item())
        prob = torch.softmax(logits.detach(), dim=1).float().cpu().numpy()
        all_p.append(prob)
        all_y.append(y.detach().cpu().numpy())

    all_p = np.concatenate(all_p, axis=0)
    all_y = np.concatenate(all_y, axis=0)
    acc,f1,auc = compute_metrics(all_y, all_p)
    return float(np.mean(losses)), acc, f1, auc

@torch.no_grad()
def validate(model, loader, criterion, is_av: bool):
    model.eval()
    losses, all_y, all_p = [], [], []
    for v,a,y in loader:
        v = v.to(device, non_blocking=True)
        a = a.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        logits = model(v,a) if is_av else model(v)
        loss = criterion(logits, y)

        losses.append(loss.item())
        prob = torch.softmax(logits, dim=1).float().cpu().numpy()
        all_p.append(prob)
        all_y.append(y.cpu().numpy())

    all_p = np.concatenate(all_p, axis=0)
    all_y = np.concatenate(all_y, axis=0)
    acc,f1,auc = compute_metrics(all_y, all_p)
    return float(np.mean(losses)), acc, f1, auc

def run_training(model, is_av: bool, epochs: int, lr: float, ckpt_path: str):
    model = model.to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=cfg.weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    scaler = GradScaler()

    weights = get_class_weights_from_train(train_df)
    criterion = nn.CrossEntropyLoss(weight=weights)

    best_f1 = -1.0
    bad = 0

    for ep in range(1, epochs + 1):
        tr = train_one_epoch(model, train_loader, optimizer, scaler, criterion, is_av=is_av)
        va = validate(model, val_loader, criterion, is_av=is_av)
        scheduler.step()

        tr_loss,tr_acc,tr_f1,tr_auc = tr
        va_loss,va_acc,va_f1,va_auc = va

        print(f"Epoch {ep:02d} | "
              f"TR loss {tr_loss:.4f} acc {tr_acc:.3f} f1 {tr_f1:.3f} auc {tr_auc:.3f} | "
              f"VA loss {va_loss:.4f} acc {va_acc:.3f} f1 {va_f1:.3f} auc {va_auc:.3f}")

        if va_f1 > best_f1:
            best_f1 = va_f1
            bad = 0
            torch.save({"model": model.state_dict()}, ckpt_path)
            print("saved best:", ckpt_path)
        else:
            bad += 1
            if bad >= cfg.patience:
                print("early stopping")
                break

    return ckpt_path

# %% [markdown]
# # Tiny Overfit Sanity Test
#
# <p style="font-size:18px; font-weight:normal;">
# This section performs a small overfitting test on a subset of 8 training samples to verify that the model and data pipeline are functioning correctly.
# If the model fails to achieve high accuracy on this tiny subset, it may indicate issues with data loading, labeling, or model implementation.
# </p>

# %%
print("\n=== Tiny Overfit Test (8 samples) ===")
tiny_idx = list(range(min(8, len(train_ds))))
tiny = torch.utils.data.Subset(train_ds, tiny_idx)
tiny_loader = DataLoader(tiny, batch_size=2, shuffle=True)

tmp_model = RealVisionAV(backbone="tf_efficientnet_b0").to(device)
tmp_opt = torch.optim.AdamW(tmp_model.parameters(), lr=2e-4)
tmp_crit = nn.CrossEntropyLoss()
tmp_scaler = GradScaler()

for ep in range(1, 6):
    tmp_model.train()
    ys, ps, losses = [], [], []
    for v,a,y in tiny_loader:
        v,a,y = v.to(device), a.to(device), y.to(device)
        tmp_opt.zero_grad(set_to_none=True)
        with autocast():
            logits = tmp_model(v,a)
            loss = tmp_crit(logits, y)
        tmp_scaler.scale(loss).backward()
        tmp_scaler.step(tmp_opt)
        tmp_scaler.update()
        losses.append(loss.item())
        ys += y.detach().cpu().tolist()
        ps += logits.argmax(1).detach().cpu().tolist()
    acc = sum(int(p==t) for p,t in zip(ps,ys)) / len(ys)
    print(ep, "loss", float(np.mean(losses)), "acc", acc)

print("If this stays ~0.5, your labels/paths are likely wrong or data is not read correctly.\n")
# Out:
# === Tiny Overfit Test (8 samples) ===
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# /tmp/ipykernel_55/2338889187.py:9: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   tmp_scaler = GradScaler()
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 1 loss 0.7685089111328125 acc 0.75
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 2 loss 0.7052135467529297 acc 0.75
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 3 loss 0.6679115295410156 acc 0.75
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 4 loss 0.46497344970703125 acc 0.75
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 5 loss 0.37957763671875 acc 0.875
# If this stays ~0.5, your labels/paths are likely wrong or data is not read correctly.
# /tmp/ipykernel_55/2338889187.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():

# %% [markdown]
# # Baseline Model Training (Video-Only)
#
# <p style="font-size:18px; font-weight:normal;">
# This section trains the video-only baseline model using spatial features extracted from video frames.
# The model serves as a reference point for evaluating the contribution of the multi-modal architecture.
# </p>

# %%
print("\n=== Train Baseline (Video-only) ===")
baseline = VideoOnlyBaseline(backbone="tf_efficientnet_b0")
baseline_ckpt = os.path.join(cfg.work_dir, "baseline_best.pt")
baseline_ckpt = run_training(baseline, is_av=False, epochs=cfg.epochs_baseline, lr=cfg.lr_baseline, ckpt_path=baseline_ckpt)
# Out:
# === Train Baseline (Video-only) ===
# /tmp/ipykernel_55/3202692664.py:72: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 01 | TR loss 0.7100 acc 0.504 f1 0.490 auc 0.489 | VA loss 0.7028 acc 0.483 f1 0.532 auc 0.478
# saved best: /kaggle/working/baseline_best.pt
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 02 | TR loss 0.6753 acc 0.566 f1 0.558 auc 0.606 | VA loss 0.6385 acc 0.637 f1 0.698 auc 0.689
# saved best: /kaggle/working/baseline_best.pt
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 03 | TR loss 0.5856 acc 0.688 f1 0.703 auc 0.757 | VA loss 0.5716 acc 0.693 f1 0.701 auc 0.758
# saved best: /kaggle/working/baseline_best.pt
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 04 | TR loss 0.4686 acc 0.786 f1 0.788 auc 0.862 | VA loss 0.5518 acc 0.717 f1 0.746 auc 0.806
# saved best: /kaggle/working/baseline_best.pt

# %% [markdown]
# # Multi-Modal Model Training (Video + Audio)
#
# <p style="font-size:18px; font-weight:normal;">
# This section trains the proposed multi-modal model that integrates spatial video features, temporal modeling, and audio representations.
# The objective is to evaluate whether combining visual and audio information improves deepfake detection performance compared to the baseline.
# </p>

# %%
print("\n=== Train Main Model (Video+Audio) ===")
av_model = RealVisionAV(backbone="tf_efficientnet_b0", v_emb=256, a_emb=256, nheads=4, nlayers=2)
av_ckpt = os.path.join(cfg.work_dir, "av_best.pt")
av_ckpt = run_training(av_model, is_av=True, epochs=cfg.epochs_av, lr=cfg.lr_av, ckpt_path=av_ckpt)
# Out:
# === Train Main Model (Video+Audio) ===
# /tmp/ipykernel_55/3202692664.py:72: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 01 | TR loss 0.7122 acc 0.503 f1 0.513 auc 0.497 | VA loss 0.7013 acc 0.500 f1 0.667 auc 0.509
# saved best: /kaggle/working/av_best.pt
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 02 | TR loss 0.7010 acc 0.496 f1 0.507 auc 0.500 | VA loss 0.6931 acc 0.507 f1 0.670 auc 0.508
# saved best: /kaggle/working/av_best.pt
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 03 | TR loss 0.6955 acc 0.511 f1 0.502 auc 0.519 | VA loss 0.6968 acc 0.490 f1 0.376 auc 0.546
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 04 | TR loss 0.6587 acc 0.611 f1 0.590 auc 0.647 | VA loss 0.6280 acc 0.653 f1 0.671 auc 0.710
# saved best: /kaggle/working/av_best.pt
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 05 | TR loss 0.5523 acc 0.730 f1 0.730 auc 0.791 | VA loss 0.6105 acc 0.673 f1 0.660 auc 0.743
# /tmp/ipykernel_55/3202692664.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 06 | TR loss 0.4641 acc 0.788 f1 0.781 auc 0.862 | VA loss 0.6114 acc 0.690 f1 0.708 auc 0.771
# saved best: /kaggle/working/av_best.pt

# %% [markdown]
# # Final Test Evaluation
#
# <p style="font-size:18px; font-weight:normal;">
# This section loads the best-performing checkpoints of both models and evaluates them on the held-out test set.
# Final performance metrics (Accuracy, F1-score, and AUC) are reported to provide an unbiased comparison between the baseline and the proposed multi-modal model.
# </p>

# %%
@torch.no_grad()
def load_best(model, ckpt_path):
    ckpt = torch.load(ckpt_path, map_location=device)
    model.load_state_dict(ckpt["model"], strict=True)
    model.to(device).eval()
    return model

@torch.no_grad()
def eval_on_test(model, loader, is_av: bool):
    model.eval()
    all_y, all_p = [], []
    for v,a,y in loader:
        v = v.to(device, non_blocking=True)
        a = a.to(device, non_blocking=True)
        logits = model(v,a) if is_av else model(v)
        prob = torch.softmax(logits, dim=1).float().cpu().numpy()
        all_p.append(prob)
        all_y.append(y.numpy())
    all_p = np.concatenate(all_p, axis=0)
    all_y = np.concatenate(all_y, axis=0)
    acc,f1,auc = compute_metrics(all_y, all_p)
    return acc,f1,auc

print("\n=== Final Test Metrics ===")
baseline2 = load_best(VideoOnlyBaseline(backbone="tf_efficientnet_b0"), baseline_ckpt)
av2       = load_best(RealVisionAV(backbone="tf_efficientnet_b0", v_emb=256, a_emb=256, nheads=4, nlayers=2), av_ckpt)

b_acc,b_f1,b_auc = eval_on_test(baseline2, test_loader, is_av=False)
a_acc,a_f1,a_auc = eval_on_test(av2, test_loader, is_av=True)

print(f"Baseline  | ACC {b_acc:.3f}  F1 {b_f1:.3f}  AUC {b_auc:.3f}")
print(f"AV Model  | ACC {a_acc:.3f}  F1 {a_f1:.3f}  AUC {a_auc:.3f}")
# Out:
# === Final Test Metrics ===
# Baseline  | ACC 0.713  F1 0.741  AUC 0.823
# AV Model  | ACC 0.737  F1 0.741  AUC 0.808

# %% [markdown]
# # Advanced Evaluation and Performance Analysis
#
# <p style="font-size:18px; font-weight:normal;">
# This section provides a comprehensive evaluation of both models using Confusion Matrices, ROC curves, Precision-Recall curves, and detailed classification reports.
# These visual and quantitative analyses offer deeper insight into class-wise performance, false positives/negatives, and the overall discriminative capability of each model.
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    RocCurveDisplay, classification_report
)

def collect_probs_and_labels(model, loader, is_av: bool):
    model.eval()
    all_y = []
    all_prob1 = []  # prob of class 1 (fake)
    with torch.no_grad():
        for v, a, y in loader:
            v = v.to(device, non_blocking=True)
            a = a.to(device, non_blocking=True)
            logits = model(v, a) if is_av else model(v)
            prob = torch.softmax(logits, dim=1)[:, 1].detach().cpu().numpy()
            all_prob1.append(prob)
            all_y.append(y.numpy())
    all_prob1 = np.concatenate(all_prob1, axis=0)
    all_y = np.concatenate(all_y, axis=0)
    return all_y, all_prob1

# Collect test predictions
y_b, p1_b = collect_probs_and_labels(baseline2, test_loader, is_av=False)
y_a, p1_a = collect_probs_and_labels(av2,       test_loader, is_av=True)

# Convert probs to predicted labels (threshold 0.5)
pred_b = (p1_b >= 0.5).astype(int)
pred_a = (p1_a >= 0.5).astype(int)

# ---- Confusion Matrices ----
plt.figure()
cm_b = confusion_matrix(y_b, pred_b, labels=[0,1])
ConfusionMatrixDisplay(cm_b, display_labels=["real(0)", "fake(1)"]).plot(values_format="d")
plt.title("Baseline - Confusion Matrix (Test)")
plt.show()

plt.figure()
cm_a = confusion_matrix(y_a, pred_a, labels=[0,1])
ConfusionMatrixDisplay(cm_a, display_labels=["real(0)", "fake(1)"]).plot(values_format="d")
plt.title("AV Model - Confusion Matrix (Test)")
plt.show()

# ---- ROC Curves ----
plt.figure()
RocCurveDisplay.from_predictions(y_b, p1_b, name="Baseline")
RocCurveDisplay.from_predictions(y_a, p1_a, name="AV Model")
plt.title("ROC Curves (Test)")
plt.show()

# ---- Per-class report ----
print("Baseline - Classification Report (Test):")
print(classification_report(y_b, pred_b, target_names=["real(0)", "fake(1)"], digits=3))

print("AV Model - Classification Report (Test):")
print(classification_report(y_a, pred_a, target_names=["real(0)", "fake(1)"], digits=3))

from sklearn.metrics import PrecisionRecallDisplay

plt.figure()
PrecisionRecallDisplay.from_predictions(y_b, p1_b, name="Baseline")
PrecisionRecallDisplay.from_predictions(y_a, p1_a, name="AV Model")
plt.title("Precision-Recall Curves (Test)")
plt.show()
# Out:
# Baseline - Classification Report (Test):
#               precision    recall  f1-score   support
#
#      real(0)      0.771     0.607     0.679       150
#      fake(1)      0.676     0.820     0.741       150
#
#     accuracy                          0.713       300
#    macro avg      0.724     0.713     0.710       300
# weighted avg      0.724     0.713     0.710       300
#
# AV Model - Classification Report (Test):
#               precision    recall  f1-score   support
#
#      real(0)      0.745     0.720     0.732       150
#      fake(1)      0.729     0.753     0.741       150
#
#     accuracy                          0.737       300
#    macro avg      0.737     0.737     0.737       300
# weighted avg      0.737     0.737     0.737       300

# %% [markdown]
# # Explainability (XAI) – Grad-CAM Visualization
#
# <p style="font-size:18px; font-weight:normal;">
# This section applies Grad-CAM to the trained multi-modal model in order to visualize which spatial regions influenced the deepfake prediction.
# The heatmap highlights the most discriminative pixels, providing interpretability and validating that the model focuses on meaningful facial areas.
# </p>

# %%
print("Loading best AV model...")

av2 = load_best(
    RealVisionAV(
        backbone="tf_efficientnet_b0",
        v_emb=256,
        a_emb=256,
        nheads=4,
        nlayers=2
    ),
    av_ckpt
)
# Out:
# Loading best AV model...

# %%
print("\n=== XAI (Grad-CAM) Setup ===")
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

target_layers = [av2.cnn.conv_head] if hasattr(av2.cnn, "conv_head") else [list(av2.cnn.modules())[-1]]

class _Wrapper(nn.Module):
    def __init__(self, model, audio_tensor, T):
        super().__init__()
        self.model = model
        self.audio = audio_tensor
        self.T = T
    def forward(self, x):
        vv = x.unsqueeze(1).repeat(1, self.T, 1, 1, 1)
        return self.model(vv, self.audio)

def gradcam_for_sample(v, a, y, title_prefix=""):
    v_in = v.unsqueeze(0).to(device)
    a_in = a.unsqueeze(0).to(device)

    # predict
    with torch.no_grad():
        logits = av2(v_in, a_in)
        prob = torch.softmax(logits, dim=1)[0].detach().cpu().numpy()
        pred = int(np.argmax(prob))

    # choose a frame
    t_idx = min(5, v.shape[0] - 1)
    frame = v_in[:, t_idx]  # (1,3,H,W)

    wrapper = _Wrapper(av2, a_in, cfg.k_frames).to(device).eval()
    cam = GradCAM(model=wrapper, target_layers=target_layers)

    grayscale_cam = cam(input_tensor=frame, targets=None)[0]  # (H,W)

    img = frame.detach().cpu().squeeze(0).permute(1,2,0).numpy()
    img = (img - img.min()) / (img.max() - img.min() + 1e-8)
    vis = show_cam_on_image(img, grayscale_cam, use_rgb=True)

    plt.figure(figsize=(6,6))
    plt.title(f"{title_prefix} | True={y} Pred={pred} ProbFake={prob[1]:.3f}")
    plt.imshow(vis)
    plt.axis("off")
    plt.show()

def find_example(test_ds, want_true, want_correct=True, max_tries=300):
    for i in range(min(max_tries, len(test_ds))):
        v, a, y = test_ds[i]
        y = int(y.item()) if hasattr(y, "item") else int(y)

        with torch.no_grad():
            logits = av2(v.unsqueeze(0).to(device), a.unsqueeze(0).to(device))
            pred = int(torch.argmax(logits, dim=1).item())

        correct = (pred == y)
        if (y == want_true) and (correct == want_correct):
            return i, v, a, y, pred
    return None
# Out:
# === XAI (Grad-CAM) Setup ===

# %%
# ===== XAI (Grad-CAM): True Real (True=0, Pred=0) =====

print("\n=== XAI: True REAL (True=0, Pred=0) ===")

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# --- safety checks ---
assert "av2" in globals(), "av2 לא מוגדר. תריצי קודם את התא של load_best + יצירת av2."
assert "test_ds" in globals(), "test_ds לא מוגדר. תריצי קודם את התא של הדאטהסט."
assert "cfg" in globals(), "cfg לא מוגדר. תריצי קודם את תא ה-Config."
assert "device" in globals(), "device לא מוגדר."

# pick a reasonable target layer
target_layers = [av2.cnn.conv_head] if hasattr(av2.cnn, "conv_head") else [list(av2.cnn.modules())[-1]]

class _Wrapper(nn.Module):
    def __init__(self, model, audio_tensor, T):
        super().__init__()
        self.model = model
        self.audio = audio_tensor
        self.T = T
    def forward(self, x):
        vv = x.unsqueeze(1).repeat(1, self.T, 1, 1, 1)
        return self.model(vv, self.audio)

@torch.no_grad()
def predict_one(v, a):
    v_in = v.unsqueeze(0).to(device)
    a_in = a.unsqueeze(0).to(device)
    logits = av2(v_in, a_in)
    prob = torch.softmax(logits, dim=1)[0].detach().cpu().numpy()
    pred = int(np.argmax(prob))
    return pred, prob

def find_true_real_example(ds, max_tries=5000):
    # want: True=0 (real) and Pred=0 (real)
    for i in range(min(max_tries, len(ds))):
        v, a, y = ds[i]
        y_int = int(y.item()) if hasattr(y, "item") else int(y)
        pred, prob = predict_one(v, a)
        if y_int == 0 and pred == 0:
            return i, v, a, y_int, pred, float(prob[1])
    return None

def gradcam_show(v, a, y_true, pred, prob_fake, title_prefix="Grad-CAM (True Real)"):
    v_in = v.unsqueeze(0).to(device)
    a_in = a.unsqueeze(0).to(device)

    # choose a frame
    t_idx = min(5, v.shape[0] - 1)
    frame = v_in[:, t_idx]  # (1,3,H,W)

    wrapper = _Wrapper(av2, a_in, cfg.k_frames).to(device).eval()
    cam = GradCAM(model=wrapper, target_layers=target_layers)

    grayscale_cam = cam(input_tensor=frame, targets=None)[0]  # (H,W)

    img = frame.detach().cpu().squeeze(0).permute(1,2,0).numpy()
    img = (img - img.min()) / (img.max() - img.min() + 1e-8)
    vis = show_cam_on_image(img, grayscale_cam, use_rgb=True)

    plt.figure(figsize=(6, 6))
    plt.title(f"{title_prefix} | True={y_true} Pred={pred} ProbFake={prob_fake:.3f}")
    plt.imshow(vis)
    plt.axis("off")
    plt.show()

res = find_true_real_example(test_ds, max_tries=5000)
if res is None:
    print("Could not find a True=0 & Pred=0 example in the first tries. נסי להגדיל max_tries או לבדוק אם המודל מנבא בעיקר 1.")
else:
    i, v, a, y_true, pred, prob_fake = res
    print(f"Using index: {i} | True={y_true} Pred={pred} ProbFake={prob_fake:.3f}")
    gradcam_show(v, a, y_true, pred, prob_fake, title_prefix="Grad-CAM (True Real)")
# Out:
# === XAI: True REAL (True=0, Pred=0) ===
# Using index: 2 | True=0 Pred=0 ProbFake=0.192

# %%
res = find_example(test_ds, want_true=1, want_correct=True)
if res is None:
    print("Could not find a correct FAKE example in the first 300 samples.")
else:
    i, v, a, y, pred = res
    print("Using index:", i, "| True:", y, "| Pred:", pred)
    gradcam_for_sample(v, a, y, title_prefix="Grad-CAM (True Fake)")
# Out:
# Using index: 0 | True: 1 | Pred: 1

# %%
# Try to find any misclassified example (either real->fake or fake->real)
found = None
for want_true in [0, 1]:
    res = find_example(test_ds, want_true=want_true, want_correct=False)
    if res is not None:
        found = res
        break

if found is None:
    print("Could not find a misclassified example in the first 300 samples.")
else:
    i, v, a, y, pred = found
    print("Using index:", i, "| True:", y, "| Pred:", pred)
    gradcam_for_sample(v, a, y, title_prefix="Grad-CAM (Misclassified)")
# Out:
# Using index: 4 | True: 0 | Pred: 1

# %% [markdown]
# #  XAI Analysis – Grad-CAM Interpretation
#
#  <p style="font-size:18px; font-weight:normal;">
# The Grad-CAM visualization highlights the spatial regions that most influenced the model’s prediction.In this example, the model focuses primarily on facial areas (eyes, nose, mouth, and skin boundaries), which are known to contain subtle inconsistencies in Deepfake manipulations.This supports the hypothesis that the network learns meaningful visual artifacts rather than relying on background or irrelevant cues, strengthening the interpretability and reliability of the proposed approach.
#  </p>
